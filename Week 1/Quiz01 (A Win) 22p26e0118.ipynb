# %%
nameList = ['Mike', 'Winn', 'Eak', 'Non']

# %%
def countnamewithalphabet(alphabet):
  count = 0
  print(alphabet)
  for name in nameList:
    if alphabet in name:
      count += 1
  return count

# %%
countnamewithalphabet('n')
# Out:
# n
# 2
